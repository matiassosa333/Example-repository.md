# %% [markdown]
# ## Challenge 1 🤺
# Escribir un programa que cree un `diccionario vacío` y lo vaya llenado con información sobre una persona (por ejemplo nombre, edad, sexo, teléfono, correo electrónico, etc.) que se le `pida al usuario`.
#
# Cada vez que se `añada` un nuevo dato debe `imprimirse` el contenido del diccionario.

# %%
Datos_usuario = {} #se crea lista vacia
#se define los valores a solicitar
nombre_usu = input("Ingrese su nombre")
apellido_usu = input("Ingrese su apellido")
edad_usu = int(input('ingrese su edad'))
sexo = input ('Ingrese su Genero')
telefono = input ('Ingrese su numero de telefono')
#A continuacion se utiliza la sintaxis correcta para cargar el diccionario vacio, cada una con un print para que vaya mostrando en terminal.
Datos_usuario["Nombre"] = nombre_usu
print (Datos_usuario)
Datos_usuario["Apellido"] = apellido_usu
print (Datos_usuario)
Datos_usuario["Edad"] = edad_usu
print (Datos_usuario)
Datos_usuario["Sexo"] = sexo
print (Datos_usuario)
Datos_usuario["Telefono"] = telefono
print (Datos_usuario)

#intento diferente

# %% [markdown]
# Crear una tarjeta personal. El usuario (mediante input) puede elegir:
#
# Crear datos nuevos
# Modificar datos
# Eliminar datos

# %%
print ('---------------Tarjeta Personalizada----------------')
Datos_dicc = {'nombre': 'Alejandro', 'correo':'alejandro@gami.com'}
print (Datos_dicc)
print('Si deseas Agregar un dato nuevo escribe 1'+'Si Desea modificar un dato escriba 2' + 'Si Desea eliminar escriba 3')
Opcion_usu = input()
if Opcion_usu == '1':
    crear_dato = Datos_dicc[input("Ingrese nombre de dato")] = input('ingrese contenido del dato')
# Out:
# ---------------Tarjeta Personalizada----------------
# {'nombre': 'Alejandro', 'correo': 'alejandro@gami.com'}
# Si deseas Agregar un dato nuevo escribe 1Si Desea modificar un dato escriba 2Si Desea eliminar escriba 3

# %% [markdown]
# Crear una agenda de contactos. El usuario puede elegir:
#
# Mostrar los contactos
# Crear contacto
# Modificar datos del contacto

# %%
print ('-------- Agenda de Contactos ----------')
Agenda_contactos = {'Edu': '0976542313', 'Olaf':'0971249943', 'Samuel E.': '0985244234'}
print ('A continuacion ingrese la opcion que desee: 1. Mostrar contactos. 2. Crear Contactos. 3. Modificar Contacto')
opcion_elegida = int(input('Ingrese su opcion'))
if opcion_elegida == 1:
    print(Agenda_contactos)
elif opcion_elegida ==2:
     crear_dato = Agenda_contactos[input("Ingrese nombre del contacto")] = input('ingrese el numero de telefono')
elif opcion_elegida == 3:
     nombre_ingresado = input("Ingrese nombre de contacto a modificar")
     numero_ingresado = input('Ingrese el numero del contacto creado')
     mod_dato = Agenda_contactos [nombre_ingresado] = (numero_ingresado)
else:
     print ('Dato incorrecto')
# Out:
# -------- Agenda de Contactos ----------
# A continuacion ingrese la opcion que desee: 1. Mostrar contactos. 2. Crear Contactos. 3. Modificar Contacto
# {'Edu': '0976542313', 'Olaf': '0971249943', 'Samuel E.': '0985244234'}
