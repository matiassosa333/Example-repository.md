# %% [markdown]
# Crear una clase animales que tenga atributo de clase y de instancia.
#
# Atributos de clase: especie.
# Atributos de instancia: nombre & color
# .
# Luego, crear nuevos objetos a partir de las nuevas class. Imprimir el nombre y el color de los animales en una frase.
# Ejemplo: "Me llamo {nombre} y soy un ave de color {color}".

# %%
class Animales: # Creamos clase llamada animales
    especie = 'gato' #creamos atributo
   
    def __init__(self, nombre, color):# funcion para construir
        self.nombre = nombre  #atributo de instancia
        self.color = color    #otro atributo instancia
gato = Animales ("garfield", "naranja") #creando el objeto
print (f'Me llamo {gato.nombre} y soy un gato de color{gato.color}')

# %% [markdown]
# Crear dos métodos para nuestro animal y ejecutar, debe ser algo específico de ese animal.
#
# Ejemplo: "Cuando hablo, digo X".
# Ejemplo: "Cuando me muevo, hago X".

# %%
class Animal: # Creamos clase llamada animales
    especie = 'Loro' #creamos atributo
   
    def __init__(self, nombre):# funcion para construir
        self.nombre = nombre  #atributo de instancia
    
    def hablar(self): #metodo
        f'Me llamo {self.nombre} Cuando hablo digo Hola'
    
    def mover(self):
        f'Cuando me muevo utilizo el pico para mas rapidez'

loro = Animal ("Oro")
(loro.mover)
(loro.hablar) 

# Ejemplo a leer 
class Animales:
    especie = "Ave"

    def init(self, nombre, color):
        self.nombre = nombre
        self.color = color

águila = Animales("Águila", "Blanco")
print(f"Me llamo {águila.nombre} y soy un {águila.especie} de color {águila.color}")

loro = Animales("Loro", "Rojo")
print(f"Me llamo {loro.nombre} y soy un {loro.especie} de color {loro.color}")

paloma = Animales("Paloma", "Gris")
print(f"Me llamo {paloma.nombre} y soy un {paloma.especie} de color {paloma.color}")
# Out:
# <bound method Animal.hablar of <__main__.Animal object at 0x0000027BDDE73950>>

# %% [markdown]
# Definir una clase madre que herede a sus clases hijas dos atributos de instancia. Mostrar ambos atributos en pantalla desde los objetos de las clases hijas.
