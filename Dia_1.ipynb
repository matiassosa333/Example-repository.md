# %%
print ('hola Mundo')
# Out:
# hola Mundo

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# esto es un markdown

# %%
Nombre = "Mathias"
Edad = 27
Ciudad = 'Fernando de la Mora'
print(Nombre, Edad, Ciudad)
# Out:
# Mathias 27 Fernando de la Mora

# %%
cantidad_de_manzanas = 1200
cantidad_de_Naranas = 3550
Cantidad_total = cantidad_de_manzanas + cantidad_de_Naranas
print ('La cantidad total de Manzanas y Naranjas son', Cantidad_total)
#Suma

Frutas_vendidas = 2370
Frutas_restantes = Cantidad_total - Frutas_vendidas
print ('La cantida de frutas restantes son:', Frutas_restantes)
# Out:
# La cantidad total de Manzanas y Naranjas son 4750
# La cantida de frutas restantes son: 2380

# %%
Nombre = 'Oscar'
apellido = 'Mereles'
Ciudad = 'San Lorenzo'
print (f'Un saludo cordial mi compañero de mesa es {Nombre} {apellido} vive en la ciudad de  {Ciudad}')
# Out:
# Un saludo cordial mi compañero de mesa es Oscar Mereles vive en la ciudad de  San Lorenzo

# %%
cantidad_caramelos = int(input('Cuantos caramelos tienes'))
cantidad_de_niños = int(input('cuantos niños son?'))
cantidad_caramelos_a_niños = cantidad_caramelos // cantidad_de_niños
Sobrante = cantidad_caramelos%cantidad_de_niños
print ('Cada niño recibira', cantidad_caramelos_a_niños, 'y sobraran', Sobrante, 'caramelos')
#Ejemplo de input mas operacion matematica
# Out:
# Cada niño recibira 6 y sobraran 2 caramelos

# %%
def configurar_brillo():
    Brillo_Maximo = input('configure brillo maximo')
    Brillo_Minimo = input('configure brillo minimo')
    print (f'configuracion de brillo maximo:{Brillo_Maximo} configuracion de Brillo minimo: {Brillo_Minimo}')

configurar_brillo()
configurar_brillo()
configurar_brillo()
# Out:
# configuracion de brillo maximo:50 configuracion de Brillo minimo: 20
# configuracion de brillo maximo:70 configuracion de Brillo minimo: 34
# configuracion de brillo maximo:90 configuracion de Brillo minimo: 76

# %%
Celular_Cliente = input('Ingrese Marca')
Modelo_Cliente= input('ingrese modelo')
def Pedido_cliente(Marca, modelo): #parametro
    print (f'Su Dispositivo {Marca} modelo {modelo} esta siendo procesada.')
    print ('Su pedido fue procesado con exito')

Pedido_cliente (Celular_Cliente, Modelo_Cliente)
# Out:
# Su Dispositivo Iphone modelo 12 Gold esta siendo procesada.
# Su pedido fue procesado con exito
